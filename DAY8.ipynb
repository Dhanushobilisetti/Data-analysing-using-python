# %%
from tensorflow.keras.models import load_model
from tenserflow.keras.preprocessing import image
im
# Out:
#   File "<ipython-input-1-ae65f9704afd>", line 3
#     import numpyas np
#                    ^
# SyntaxError: invalid syntax
