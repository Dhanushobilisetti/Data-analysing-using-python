# %%
import requests
api_key='9d3aebff3ce945e498555850242802'
city='EluRu'
url=f" http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
response=requests.get(url)
data=response.json()
print(data)
# Out:
# {'location': {'name': 'Eluru', 'region': 'Andhra Pradesh', 'country': 'India', 'lat': 16.7, 'lon': 81.1, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1709100633, 'localtime': '2024-02-28 11:40'}, 'current': {'last_updated_epoch': 1709100000, 'last_updated': '2024-02-28 11:30', 'temp_c': 30.0, 'temp_f': 86.0, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 5.6, 'wind_kph': 9.0, 'wind_degree': 120, 'wind_dir': 'ESE', 'pressure_mb': 1014.0, 'pressure_in': 29.94, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 59, 'cloud': 25, 'feelslike_c': 29.2, 'feelslike_f': 84.6, 'vis_km': 6.0, 'vis_miles': 3.0, 'uv': 8.0, 'gust_mph': 7.5, 'gust_kph': 12.0}}

# %%
type(data)
dict
# Out:
# dict

# %%
import requests
api_key='9d3aebff3ce945e498555850242802'
city=input("Enter a city name")
url=f" http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
response=requests.get(url)
data=response.json()
print(data)
# Out:
# Enter a city nameTadepalligudem
# {'location': {'name': 'Tadepalligudem', 'region': 'Andhra Pradesh', 'country': 'India', 'lat': 16.83, 'lon': 81.5, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1709100788, 'localtime': '2024-02-28 11:43'}, 'current': {'last_updated_epoch': 1709100000, 'last_updated': '2024-02-28 11:30', 'temp_c': 33.9, 'temp_f': 93.0, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 5.1, 'wind_kph': 8.3, 'wind_degree': 117, 'wind_dir': 'ESE', 'pressure_mb': 1013.0, 'pressure_in': 29.92, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 32, 'cloud': 3, 'feelslike_c': 34.2, 'feelslike_f': 93.5, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 8.0, 'gust_mph': 5.9, 'gust_kph': 9.5}}

# %%
import requests
api_key='9d3aebff3ce945e498555850242802'
city=input("Enter a city name")
url=f" http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
response=requests.get(url)
data=response.json()
print("city",data['location']['name'])
print("state",data['location']['region'])
print("country",data['location']['country'])
print("temperature",data['current']['temp_c'])
print("wind direction",data['current']['wind_dir'])
print("wind speed"),data['current']['wind_mph']
print("humidity"),data['current']['humidity']
print("feels like"),data['current']['feelslike_c']
# Out:
# Enter a city nameTadepalligudem
# city Tadepalligudem
# state Andhra Pradesh
# country India
# temperature 33.9
# wind direction ESE
# wind speed
# humidity
# feels like
# (None, 34.2)

# %%
import requests
api_key='9d3aebff3ce945e498555850242802'
city=input("Enter a city name")
url=f" http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
response=requests.get(url)
data=response.json()
print(data)
if response.status_code==200:
    print("city",data['location']['name'])
    print("state",data['location']['region'])
    print("country",data['location']['country'])
    print("temperature",data['current']['temp_c'])
    print("wind direction",data['current']['wind_dir'])
    print("wind speed"),data['current']['wind_mph']
    print("humidity"),data['current']['humidity']
    print("feels like"),data['current']['feelslike_c']
else:
  print("error")
# Out:
# Enter a city nameTadepalligudem
# {'location': {'name': 'Tadepalligudem', 'region': 'Andhra Pradesh', 'country': 'India', 'lat': 16.83, 'lon': 81.5, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1709102179, 'localtime': '2024-02-28 12:06'}, 'current': {'last_updated_epoch': 1709101800, 'last_updated': '2024-02-28 12:00', 'temp_c': 35.6, 'temp_f': 96.1, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 4.3, 'wind_kph': 6.8, 'wind_degree': 103, 'wind_dir': 'ESE', 'pressure_mb': 1012.0, 'pressure_in': 29.87, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 26, 'cloud': 8, 'feelslike_c': 35.2, 'feelslike_f': 95.4, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 9.0, 'gust_mph': 4.9, 'gust_kph': 7.9}}
# city Tadepalligudem
# state Andhra Pradesh
# country India
# temperature 35.6
# wind direction ESE
# wind speed
# humidity
# feels like
